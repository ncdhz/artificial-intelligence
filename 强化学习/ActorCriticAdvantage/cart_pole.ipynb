# %%
import numpy as np
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class Net(nn.Module):
	def __init__(self, n_feature, n_hidden, n_output, activate=False):
		super(Net, self).__init__()
		self.l1 = nn.Linear(n_feature, n_hidden)
		self.acts_prob = nn.Linear(n_hidden, n_output)
		self.activate=activate
		
	def forward(self, x):
		x = self.l1(x)
		x = F.relu(x)
		x = self.acts_prob(x)
		if self.activate:
			x = F.softmax(x, dim=1)
		return x

# %%
class Actor(object):
	def __init__(self, n_features, n_actions, n_hidden=20, lr=0.001):
		self.n_features = n_features
		self.n_actions = n_actions
		self.n_hidden = n_hidden
		self.lr = lr
		self.__build_net()


	def __build_net(self):
		self.actor_net = Net(self.n_features, self.n_hidden, self.n_actions, activate=True)
		self.optimizer = torch.optim.Adam(self.actor_net.parameters(), lr=self.lr)


	def choose_action(self, s):
		s = torch.Tensor(s[np.newaxis, :])
		probs = self.actor_net(s)
		return np.random.choice(np.arange(probs.shape[1]), p=probs.data.numpy().ravel())


	def learn(self, s, a, td):
		s = torch.Tensor(s[np.newaxis, :])
		acts_prob = self.actor_net(s)
		log_prob = torch.log(acts_prob[0, a])
		exp_v = torch.mean(log_prob * td.detach())
		
		loss = -exp_v
		self.optimizer.zero_grad()
		loss.backward(retain_graph=True)
		self.optimizer.step()

		return exp_v

# %%
class Critic(object):
    def __init__(self, n_features, lr=0.01, gamma=0.9):
        self.n_features = n_features
        self.lr = lr
        self.gamma = gamma
        self._build_net()

    def _build_net(self):
        self.critic_net = Net(self.n_features, 20, 1)
        self.optimizer = torch.optim.Adam(self.critic_net.parameters(), lr=self.lr)


    def learn(self, s, r, s_):
        s, s_ = torch.Tensor(s[np.newaxis, :]), torch.Tensor(s_[np.newaxis, :])
        v, v_ = self.critic_net(s), self.critic_net(s_)
        td_error = r + self.gamma * v_ - v
        loss = td_error ** 2

        self.optimizer.zero_grad()
        loss.backward(retain_graph=True)
        self.optimizer.step()

        return td_error

# %%
env = gym.make('CartPole-v0')
env = env.unwrapped

# %%
MAX_EPISODE = 3000
DISPLAY_REWARD_THRESHOLD =  200   # renders environment if total episode reward is greater than this threshold
MAX_EP_STEPS = 1000   # maximum time steps in one episode
RENDER = False   # rendering wastes time
LR_A = 0.001   # learning rate for actor
LR_C = 0.01   # learning rete for critic
N_F = env.observation_space.shape[0]
N_A = env.action_space.n

# %%
actor = Actor(n_features=N_F, n_actions=N_A, lr=LR_A)
# we need a good teacher, so the teacher should learn faster than the actor
critic = Critic(n_features=N_F, lr=LR_C)

# %%
for i_episode in range(MAX_EPISODE):
	s = env.reset()
	t = 0
	track_r = []

	while True:
		if RENDER: env.render()

		a = actor.choose_action(s)

		s_, r, done, info = env.step(a)

		if done: r = -20

		track_r.append(r)

		td_error = critic.learn(s, r, s_)  # gradient = grad[r + gamma * V(s_) - V(s)]
		actor.learn(s, a, td_error)   # true_gradient = grad[logPi(s, a) * td_error]

		s = s_
		t += 1

		if done or t >= MAX_EP_STEPS:
			ep_rs_sum = sum(track_r)

			if 'running_reward' not in globals():
				running_reward = ep_rs_sum
			else:
				running_reward = running_reward * 0.95 + ep_rs_sum * 0.05

			if running_reward > DISPLAY_REWARD_THRESHOLD: RENDER = True
			print("episode: ", i_episode, "  reward:", int(running_reward))
			break
# Out:
# episode:  0   reward: -9
# episode:  1   reward: -9
# episode:  2   reward: -8
# episode:  3   reward: -8
# episode:  4   reward: -7
# episode:  5   reward: -7
# episode:  6   reward: -7
# episode:  7   reward: -7
# episode:  8   reward: -7
# episode:  9   reward: -6
# episode:  10   reward: -5
# episode:  11   reward: -4
# episode:  12   reward: -4
# episode:  13   reward: -4
# episode:  14   reward: -4
# episode:  15   reward: -3
# episode:  16   reward: -3
# episode:  17   reward: -3
# episode:  18   reward: -1
# episode:  19   reward: -1
# episode:  20   reward: 0
# episode:  21   reward: 0
# episode:  22   reward: 0
# episode:  23   reward: 0
# episode:  24   reward: 0
# episode:  25   reward: 0
# episode:  26   reward: 0
# episode:  27   reward: 0
# episode:  28   reward: 0
# episode:  29   reward: 0
# episode:  30   reward: 0
# episode:  31   reward: 0
# episode:  32   reward: 0
# episode:  33   reward: 2
# episode:  34   reward: 3
# episode:  35   reward: 3
# episode:  36   reward: 2
# episode:  37   reward: 2
# episode:  38   reward: 3
# episode:  39   reward: 2
# episode:  40   reward: 3
# episode:  41   reward: 3
# episode:  42   reward: 5
# episode:  43   reward: 5
# episode:  44   reward: 5
# episode:  45   reward: 5
# episode:  46   reward: 7
# episode:  47   reward: 7
# episode:  48   reward: 8
# episode:  49   reward: 7
# episode:  50   reward: 6
# episode:  51   reward: 6
# episode:  52   reward: 5
# episode:  53   reward: 6
# episode:  54   reward: 7
# episode:  55   reward: 6
# episode:  56   reward: 7
# episode:  57   reward: 6
# episode:  58   reward: 6
# episode:  59   reward: 8
# episode:  60   reward: 7
# episode:  61   reward: 7
# episode:  62   reward: 7
# episode:  63   reward: 7
# episode:  64   reward: 6
# episode:  65   reward: 7
# episode:  66   reward: 8
# episode:  67   reward: 7
# episode:  68   reward: 8
# episode:  69   reward: 7
# episode:  70   reward: 6
# episode:  71   reward: 6
# episode:  72   reward: 6
# episode:  73   reward: 5
# episode:  74   reward: 5
# episode:  75   reward: 6
# episode:  76   reward: 5
# episode:  77   reward: 6
# episode:  78   reward: 6
# episode:  79   reward: 6
# episode:  80   reward: 6
# episode:  81   reward: 5
# episode:  82   reward: 5
# episode:  83   reward: 7
# episode:  84   reward: 9
# episode:  85   reward: 11
# episode:  86   reward: 10
# episode:  87   reward: 9
# episode:  88   reward: 9
# episode:  89   reward: 9
# episode:  90   reward: 9
# episode:  91   reward: 8
# episode:  92   reward: 8
# episode:  93   reward: 10
# episode:  94   reward: 11
# episode:  95   reward: 10
# episode:  96   reward: 10
# episode:  97   reward: 9
# episode:  98   reward: 9
# episode:  99   reward: 8
# episode:  100   reward: 8
# episode:  101   reward: 7
# episode:  102   reward: 7
# episode:  103   reward: 7
# episode:  104   reward: 7
# episode:  105   reward: 6
# episode:  106   reward: 6
# episode:  107   reward: 5
# episode:  108   reward: 5
# episode:  109   reward: 4
# episode:  110   reward: 4
# episode:  111   reward: 5
# episode:  112   reward: 6
# episode:  113   reward: 6
# episode:  114   reward: 7
# episode:  115   reward: 7
# episode:  116   reward: 9
# episode:  117   reward: 9
# episode:  118   reward: 9
# episode:  119   reward: 9
# episode:  120   reward: 9
# episode:  121   reward: 8
# episode:  122   reward: 9
# episode:  123   reward: 8
# episode:  124   reward: 10
# episode:  125   reward: 11
# episode:  126   reward: 12
# episode:  127   reward: 11
# episode:  128   reward: 11
# episode:  129   reward: 12
# episode:  130   reward: 12
# episode:  131   reward: 12
# episode:  132   reward: 12
# episode:  133   reward: 11
# episode:  134   reward: 12
# episode:  135   reward: 12
# episode:  136   reward: 13
# episode:  137   reward: 14
# episode:  138   reward: 13
# episode:  139   reward: 13
# episode:  140   reward: 13
# episode:  141   reward: 13
# episode:  142   reward: 13
# episode:  143   reward: 13
# episode:  144   reward: 12
# episode:  145   reward: 12
# episode:  146   reward: 13
# episode:  147   reward: 13
# episode:  148   reward: 13
# episode:  149   reward: 13
# episode:  150   reward: 12
# episode:  151   reward: 11
# episode:  152   reward: 11
# episode:  153   reward: 12
# episode:  154   reward: 11
# episode:  155   reward: 12
# episode:  156   reward: 13
# episode:  157   reward: 12
# episode:  158   reward: 14
# episode:  159   reward: 13
# episode:  160   reward: 12
# episode:  161   reward: 13
# episode:  162   reward: 13
# episode:  163   reward: 12
# episode:  164   reward: 11
# episode:  165   reward: 12
# episode:  166   reward: 11
# episode:  167   reward: 11
# episode:  168   reward: 10
# episode:  169   reward: 11
# episode:  170   reward: 11
# episode:  171   reward: 12
# episode:  172   reward: 12
# episode:  173   reward: 12
# episode:  174   reward: 13
# episode:  175   reward: 12
# episode:  176   reward: 14
# episode:  177   reward: 15
# episode:  178   reward: 15
# episode:  179   reward: 15
# episode:  180   reward: 14
# episode:  181   reward: 14
# episode:  182   reward: 15
# episode:  183   reward: 18
# episode:  184   reward: 19
# episode:  185   reward: 19
# episode:  186   reward: 21
# episode:  187   reward: 23
# episode:  188   reward: 24
# episode:  189   reward: 23
# episode:  190   reward: 23
# episode:  191   reward: 23
# episode:  192   reward: 23
# episode:  193   reward: 22
# episode:  194   reward: 21
# episode:  195   reward: 21
# episode:  196   reward: 21
# episode:  197   reward: 20
# episode:  198   reward: 19
# episode:  199   reward: 19
# episode:  200   reward: 19
# episode:  201   reward: 20
# episode:  202   reward: 21
# episode:  203   reward: 20
# episode:  204   reward: 22
# episode:  205   reward: 29
# episode:  206   reward: 28
# episode:  207   reward: 27
# episode:  208   reward: 28
# episode:  209   reward: 28
# episode:  210   reward: 28
# episode:  211   reward: 28
# episode:  212   reward: 28
# episode:  213   reward: 28
# episode:  214   reward: 27
# episode:  215   reward: 28
# episode:  216   reward: 27
# episode:  217   reward: 26
# episode:  218   reward: 26
# episode:  219   reward: 26
# episode:  220   reward: 25
# episode:  221   reward: 26
# episode:  222   reward: 25
# episode:  223   reward: 25
# episode:  224   reward: 29
# episode:  225   reward: 29
# episode:  226   reward: 28
# episode:  227   reward: 27
# episode:  228   reward: 26
# episode:  229   reward: 26
# episode:  230   reward: 25
# episode:  231   reward: 26
# episode:  232   reward: 25
# episode:  233   reward: 26
# episode:  234   reward: 28
# episode:  235   reward: 28
# episode:  236   reward: 27
# episode:  237   reward: 27
# episode:  238   reward: 27
# episode:  239   reward: 26
# episode:  240   reward: 27
# episode:  241   reward: 26
# episode:  242   reward: 28
# episode:  243   reward: 28
# episode:  244   reward: 28
# episode:  245   reward: 27
# episode:  246   reward: 25
# episode:  247   reward: 24
# episode:  248   reward: 23
# episode:  249   reward: 24
# episode:  250   reward: 27
# episode:  251   reward: 26
# episode:  252   reward: 25
# episode:  253   reward: 24
# episode:  254   reward: 23
# episode:  255   reward: 25
# episode:  256   reward: 26
# episode:  257   reward: 25
# episode:  258   reward: 28
# episode:  259   reward: 29
# episode:  260   reward: 29
# episode:  261   reward: 28
# episode:  262   reward: 32
# episode:  263   reward: 32
# episode:  264   reward: 37
# episode:  265   reward: 37
# episode:  266   reward: 36
# episode:  267   reward: 39
# episode:  268   reward: 39
# episode:  269   reward: 38
# episode:  270   reward: 37
# episode:  271   reward: 38
# episode:  272   reward: 39
# episode:  273   reward: 38
# episode:  274   reward: 37
# episode:  275   reward: 36
# episode:  276   reward: 38
# episode:  277   reward: 39
# episode:  278   reward: 41
# episode:  279   reward: 42
# episode:  280   reward: 41
# episode:  281   reward: 40
# episode:  282   reward: 40
# episode:  283   reward: 40
# episode:  284   reward: 40
# episode:  285   reward: 41
# episode:  286   reward: 44
# episode:  287   reward: 43
# episode:  288   reward: 42
# episode:  289   reward: 41
# episode:  290   reward: 41
# episode:  291   reward: 41
# episode:  292   reward: 44
# episode:  293   reward: 44
# episode:  294   reward: 44
# episode:  295   reward: 44
# episode:  296   reward: 48
# episode:  297   reward: 48
# episode:  298   reward: 52
# episode:  299   reward: 51
# episode:  300   reward: 52
# episode:  301   reward: 52
# episode:  302   reward: 57
# episode:  303   reward: 57
# episode:  304   reward: 55
# episode:  305   reward: 55
# episode:  306   reward: 54
# episode:  307   reward: 53
# episode:  308   reward: 54
# episode:  309   reward: 53
# episode:  310   reward: 57
# episode:  311   reward: 57
# episode:  312   reward: 56
# episode:  313   reward: 54
# episode:  314   reward: 52
# episode:  315   reward: 54
# episode:  316   reward: 54
# episode:  317   reward: 56
# episode:  318   reward: 55
# episode:  319   reward: 55
# episode:  320   reward: 53
# episode:  321   reward: 57
# episode:  322   reward: 60
# episode:  323   reward: 59
# episode:  324   reward: 57
# episode:  325   reward: 56
# episode:  326   reward: 60
# episode:  327   reward: 63
# episode:  328   reward: 61
# episode:  329   reward: 59
# episode:  330   reward: 64
# episode:  331   reward: 61
# episode:  332   reward: 62
# episode:  333   reward: 63
# episode:  334   reward: 64
# episode:  335   reward: 62
# episode:  336   reward: 63
# episode:  337   reward: 63
# episode:  338   reward: 68
# episode:  339   reward: 70
# episode:  340   reward: 73
# episode:  341   reward: 73
# episode:  342   reward: 73
# episode:  343   reward: 73
# episode:  344   reward: 73
# episode:  345   reward: 71
# episode:  346   reward: 69
# episode:  347   reward: 69
# episode:  348   reward: 66
# episode:  349   reward: 69
# episode:  350   reward: 71
# episode:  351   reward: 78
# episode:  352   reward: 79
# episode:  353   reward: 77
# episode:  354   reward: 74
# episode:  355   reward: 76
# episode:  356   reward: 80
# episode:  357   reward: 80
# episode:  358   reward: 86
# episode:  359   reward: 88
# episode:  360   reward: 87
# episode:  361   reward: 87
# episode:  362   reward: 85
# episode:  363   reward: 90
# episode:  364   reward: 91
# episode:  365   reward: 88
# episode:  366   reward: 89
# episode:  367   reward: 99
# episode:  368   reward: 100
# episode:  369   reward: 101
# episode:  370   reward: 100
# episode:  371   reward: 100
# episode:  372   reward: 98
# episode:  373   reward: 97
# episode:  374   reward: 97
# episode:  375   reward: 101
# episode:  376   reward: 103
# episode:  377   reward: 106
# episode:  378   reward: 108
# episode:  379   reward: 109
# episode:  380   reward: 110
# episode:  381   reward: 111
# episode:  382   reward: 111
# episode:  383   reward: 110
# episode:  384   reward: 111
# episode:  385   reward: 110
# episode:  386   reward: 113
# episode:  387   reward: 124
# episode:  388   reward: 122
# episode:  389   reward: 117
# episode:  390   reward: 114
# episode:  391   reward: 109
# episode:  392   reward: 109
# episode:  393   reward: 108
# episode:  394   reward: 112
# episode:  395   reward: 107
# episode:  396   reward: 106
# episode:  397   reward: 107
# episode:  398   reward: 104
# episode:  399   reward: 105
# episode:  400   reward: 106
# episode:  401   reward: 107
# episode:  402   reward: 106
# episode:  403   reward: 103
# episode:  404   reward: 103
# episode:  405   reward: 103
# episode:  406   reward: 110
# episode:  407   reward: 110
# episode:  408   reward: 109
# episode:  409   reward: 105
# episode:  410   reward: 100
# episode:  411   reward: 97
# episode:  412   reward: 94
# episode:  413   reward: 92
# episode:  414   reward: 91
# episode:  415   reward: 88
# episode:  416   reward: 86
# episode:  417   reward: 83
# episode:  418   reward: 82
# episode:  419   reward: 85
# episode:  420   reward: 84
# episode:  421   reward: 87
# episode:  422   reward: 87
# episode:  423   reward: 91
# episode:  424   reward: 99
# episode:  425   reward: 99
# episode:  426   reward: 101
# episode:  427   reward: 114
# episode:  428   reward: 109
# episode:  429   reward: 109
# episode:  430   reward: 106
# episode:  431   reward: 103
# episode:  432   reward: 101
# episode:  433   reward: 99
# episode:  434   reward: 97
# episode:  435   reward: 94
# episode:  436   reward: 94
# episode:  437   reward: 98
# episode:  438   reward: 100
# episode:  439   reward: 99
# episode:  440   reward: 99
# episode:  441   reward: 98
# episode:  442   reward: 100
# episode:  443   reward: 107
# episode:  444   reward: 108
# episode:  445   reward: 105
# episode:  446   reward: 107
# episode:  447   reward: 105
# episode:  448   reward: 102
# episode:  449   reward: 102
# episode:  450   reward: 109
# episode:  451   reward: 109
# episode:  452   reward: 125
# episode:  453   reward: 122
# episode:  454   reward: 117
# episode:  455   reward: 115
# episode:  456   reward: 113
# episode:  457   reward: 111
# episode:  458   reward: 113
# episode:  459   reward: 115
# episode:  460   reward: 112
# episode:  461   reward: 115
# episode:  462   reward: 117
# episode:  463   reward: 121
# episode:  464   reward: 128
# episode:  465   reward: 125
# episode:  466   reward: 134
# episode:  467   reward: 132
# episode:  468   reward: 134
# episode:  469   reward: 134
# episode:  470   reward: 135
# episode:  471   reward: 136
# episode:  472   reward: 131
# episode:  473   reward: 129
# episode:  474   reward: 126
# episode:  475   reward: 124
# episode:  476   reward: 121
# episode:  477   reward: 120
# episode:  478   reward: 123
# episode:  479   reward: 123
# episode:  480   reward: 124
# episode:  481   reward: 134
# episode:  482   reward: 135
# episode:  483   reward: 141
# episode:  484   reward: 150
# episode:  485   reward: 149
# episode:  486   reward: 154
# episode:  487   reward: 154
# episode:  488   reward: 166
# episode:  489   reward: 165
# episode:  490   reward: 161
# episode:  491   reward: 163
# episode:  492   reward: 162
# episode:  493   reward: 167
# episode:  494   reward: 170
# episode:  495   reward: 174
# episode:  496   reward: 174
# episode:  497   reward: 170
# episode:  498   reward: 172
# episode:  499   reward: 175
# episode:  500   reward: 170
# episode:  501   reward: 166
# episode:  502   reward: 164
# episode:  503   reward: 164
# episode:  504   reward: 163
# episode:  505   reward: 160
# episode:  506   reward: 158
# episode:  507   reward: 154
# episode:  508   reward: 152
# episode:  509   reward: 150
# episode:  510   reward: 150
# episode:  511   reward: 150
# episode:  512   reward: 156
# episode:  513   reward: 155
# episode:  514   reward: 154
# episode:  515   reward: 154
# episode:  516   reward: 153
# episode:  517   reward: 150
# episode:  518   reward: 161
# episode:  519   reward: 156
# episode:  520   reward: 153
# episode:  521   reward: 151
# episode:  522   reward: 148
# episode:  523   reward: 147
# episode:  524   reward: 147
# episode:  525   reward: 146
# episode:  526   reward: 148
# episode:  527   reward: 153
# episode:  528   reward: 162
# episode:  529   reward: 162
# episode:  530   reward: 162
# episode:  531   reward: 163
# episode:  532   reward: 167
# episode:  533   reward: 189
# episode:  534   reward: 196
# episode:  535   reward: 197
# episode:  536   reward: 200
# episode:  537   reward: 212
# episode:  538   reward: 213
# episode:  539   reward: 210
# episode:  540   reward: 204
# episode:  541   reward: 214
# episode:  542   reward: 214
# episode:  543   reward: 213
# episode:  544   reward: 203
# episode:  545   reward: 197
# episode:  546   reward: 194
# episode:  547   reward: 190
# episode:  548   reward: 188
# episode:  549   reward: 187
# episode:  550   reward: 204
# episode:  551   reward: 203
# episode:  552   reward: 207
# episode:  553   reward: 220
# episode:  554   reward: 236
# episode:  555   reward: 231
# episode:  556   reward: 239
# episode:  557   reward: 249
# episode:  558   reward: 241
# episode:  559   reward: 253
# episode:  560   reward: 249
# episode:  561   reward: 243
# episode:  562   reward: 237
# episode:  563   reward: 237
# episode:  564   reward: 236
# episode:  565   reward: 237
# episode:  566   reward: 231
# episode:  567   reward: 223
# episode:  568   reward: 220
# episode:  569   reward: 214
# episode:  570   reward: 205
# episode:  571   reward: 200
# episode:  572   reward: 192
# episode:  573   reward: 188
# episode:  574   reward: 185
# episode:  575   reward: 177
# episode:  576   reward: 168
# episode:  577   reward: 161
# episode:  578   reward: 155
# episode:  579   reward: 147
# episode:  580   reward: 140
# episode:  581   reward: 134
# episode:  582   reward: 128
# episode:  583   reward: 122
# episode:  584   reward: 116
# episode:  585   reward: 111
# episode:  586   reward: 106
# episode:  587   reward: 102
# episode:  588   reward: 97
# episode:  589   reward: 92
# episode:  590   reward: 88
# episode:  591   reward: 84
# episode:  592   reward: 79
# episode:  593   reward: 75
# episode:  594   reward: 72
# episode:  595   reward: 68
# episode:  596   reward: 65
# episode:  597   reward: 62
# episode:  598   reward: 59
# episode:  599   reward: 56
# episode:  600   reward: 52
# episode:  601   reward: 49
# episode:  602   reward: 48
# episode:  603   reward: 45
# episode:  604   reward: 42
# episode:  605   reward: 40
# episode:  606   reward: 38
# episode:  607   reward: 37
# episode:  608   reward: 35
# episode:  609   reward: 34
# episode:  610   reward: 32
# episode:  611   reward: 30
# episode:  612   reward: 28
# episode:  613   reward: 27
# episode:  614   reward: 26
# episode:  615   reward: 24
# episode:  616   reward: 23
# episode:  617   reward: 23
